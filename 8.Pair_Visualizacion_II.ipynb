# %%
# importamos las librerías que necesitamos
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
# Futuros warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
df = pd.read_csv("world_data_full_apply_nulos.csv", index_col=0)
df.head(5)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %% [markdown]
# # Visualización II
# Ejercicios visualización
#
# A lo largo de este ejercicio plantearemos una serie de preguntas que tendrás que contestar usando la visualización (podréis usar tanto Seaborn como Matplotlib).
#
# . En estos ejercicios debes decidir que gráfica es más adecuada. Puedes utilizar cualquier gráfica vista hasta el momento: gráficas para variables numéricas, categóricas o relación entre ambas.

# %%
# ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 194
# Data columns (total 36 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               195 non-null    object
#  1   density                               195 non-null    float64
#  2   abbreviation                          188 non-null    object
#  3   agricultural_land                     188 non-null    float64
#  4   land_area                             165 non-null    float64
#  5   armed_forces_size                     166 non-null    float64
#  6   birth_rate                            189 non-null    float64
#  7   calling_code                          194 non-null    float64
#  8   capital/major_city                    192 non-null    object
#  9   co2-emissions                         183 non-null    float64
#  10  cpi                                   175 non-null    float64
# ...

# %%
df.groupby('continent')['country'].count().reset_index()
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2
# 5          Oceania       14
# 6    South America       13

# %%
sns.countplot(data=df, y='continent')
# Out:
# <Axes: xlabel='count', ylabel='continent'>

# %%
plt.pie(data = df.groupby('continent')['country'].count().reset_index(), x= 'country', labels='continent', autopct='%1.1f%%')
plt.title('Porcentaje de países por continente')
# Out:
# Text(0.5, 1.0, 'Porcentaje de países por continente')

# %%
plt.pie(df['continent'].value_counts(), labels=df['continent'].value_counts().index, autopct='%1.1f%%');

# %%
# ¿Cuáles son los 10 países con la mayor área forestal?

# %%
df.groupby('country')['forested_area'].value_counts().sort_values(ascending=False).head(10)
# Out:
# country           forested_area
# Afghanistan       2.1              1
# Philippines       27.8             1
# North Korea       40.7             1
# Norway            33.2             1
# Oman              0.0              1
# Pakistan          1.9              1
# Palau             87.6             1
# Panama            61.9             1
# Papua New Guinea  74.1             1
# Paraguay          37.7             1
# Name: count, dtype: int64

# %%
df.groupby('country')['forested_area'].sum().sort_values(ascending=False).head(10)
# Out:
# country
# Suriname                          98.3
# Federated States of Micronesia    91.9
# Gabon                             90.0
# Seychelles                        88.4
# Palau                             87.6
# Guyana                            83.9
# Laos                              82.1
# Solomon Islands                   77.9
# Papua New Guinea                  74.1
# Finland                           73.1
# Name: forested_area, dtype: float64

# %%
dfarea = df.groupby('country')['forested_area'].sum().sort_values(ascending=False).head(10)

# %%
sns.barplot(x ='forested_area', y = dfarea.index, data = dfarea.reset_index(), color = 'green')
plt.title('Top 10 países con mayor área forestal')
plt.xlabel('Área forestal (en km²)')
# Out:
# Text(0.5, 0, 'Área forestal (en km²)')

# %%
# ¿Cómo se distribuye la densidad de población entre los países?

# %%
df.groupby('country')['density'].value_counts().reset_index()
# Out:
#          country  density  count
# 0    Afghanistan     60.0      1
# 1        Albania    105.0      1
# 2        Algeria     18.0      1
# 3        Andorra    164.0      1
# 4         Angola     26.0      1
# ..           ...      ...    ...
# 190    Venezuela     32.0      1
# 191      Vietnam    314.0      1
# 192        Yemen     56.0      1
# 193       Zambia     25.0      1
# 194     Zimbabwe     38.0      1
#
# [195 rows x 3 columns]

# %%
#el grafico de debajo está mal (scatterplot), no es adecuada dado que no son datos numéricos

# %%
sns.scatterplot(y = "country", 
                x = "density", 
                data = df, 
                size = 2, 
                marker= "v",
                color = "purple")
# Out:
# <Axes: xlabel='density', ylabel='country'>

# %%
sns.barplot(x='density', y='country', data= df.sort_values('density', ascending=False).head(10), color = 'purple')

plt.title('densidad de población por país')
# Out:
# Text(0.5, 1.0, 'densidad de población por país')

# %%
# ¿Existe una relación entre el PIB y la tasa de desempleo de los países?

# %%
# ¿Cómo se relacionan la tasa de mortalidad infantil y la esperanza de vida?

# %% [markdown]
# Requisitos que deben cumplir las gráficas (en caso de usar alguna de ellas):
#
# Todas deben llevar título.
#
# Los nombres de los ejes deben estar en castellano.
#
# En los scatterplot los puntos deben tener un tamaño de 2.
#
# En los scatterplot los puntos deben tener un color diferente al azul.
#
# En los barplot las barras siempre tienen que estar ordenadas de mayor a menor.
#
# En los barplot y countplot las barras tienen que tener un color diferente a los que vienen por defecto.
#
# En los pieplot siempre tenemos que añadir la etiqueta de a que % corresponde cada quesito.
